# %% [raw]
# ## Retriving Dataset
# ## https://github.com/CSSEGISandData/COVID-19.git
# ## ! python3 -m pip install wget
# ## ! python3 -m pip install pandas
# ## !python3 -m pip install pycountry_convert

# %%
import pandas as pd
import numpy as np

import wget
import os, datetime
import shutil

import pycountry_convert as pc

# %%
# global csv files
csv_confirmed = "time_series_covid19_confirmed_US.csv"
csv_deaths = "time_series_covid19_deaths_US.csv"

# %%
# urls of the files
urls = ['https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv', 
        'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv']

# download files
for url in urls:
    filename = wget.download(url)

# %%
currDir = "./COVID-19-data-US"
backupDir = "./COVID-19-data-US-" + datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

isdir = os.path.isdir(currDir) 

if isdir:
    try:
        os.rename(currDir, backupDir)
    except OSError:
        print ("Rename of the directory %s failed" % backupDir)

try:
    os.mkdir(currDir)
except OSError:
    print ("Creation of the directory %s failed" % currDir)
else:
    print ("Successfully created the directory %s " % currDir)
# Out:
# Successfully created the directory ./COVID-19-data-US

# %%
for file in os.listdir(os.getcwd()):
    if '.csv' in file:
        print(file)
        shutil.move(file, currDir)
# Out:
# time_series_covid19_confirmed_US.csv
# time_series_covid19_deaths_US.csv

# %%
# Datasets loaded to DataFrame
df_confirmed = pd.read_csv("./COVID-19-data-US/time_series_covid19_confirmed_US.csv")
df_deaths = pd.read_csv("./COVID-19-data-US/time_series_covid19_deaths_US.csv")

# %%
df_confirmed.columns
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_',
#        ...
#        '4/12/20', '4/13/20', '4/14/20', '4/15/20', '4/16/20', '4/17/20',
#        '4/18/20', '4/19/20', '4/20/20', '4/21/20'],
#       dtype='object', length=102)

# %%
ids = df_confirmed.columns[0:11]
us_dates = df_confirmed.columns[11:]

us_conf_df_long = df_confirmed.melt(id_vars=ids, value_vars=us_dates, var_name='Date', value_name='Confirmed')
us_deaths_df_long = df_deaths.melt(id_vars=ids, value_vars=us_dates, var_name='Date', value_name='Deaths')

print(us_conf_df_long.shape)
print(us_deaths_df_long.shape)
# Out:
# (297479, 13)
# (297479, 13)

# %%
us_conf_df_long.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed
# 0 -14.2710 -170.1320            American Samoa, US  1/22/20          0
# 1  13.4443  144.7937                      Guam, US  1/22/20          0
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0

# %%
ft_ids = us_conf_df_long.columns[:-1]
ft_ids
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Date'],
#       dtype='object')

# %%
us_full_table = pd.concat([us_conf_df_long, us_deaths_df_long[['Deaths']]], axis=1)
us_full_table.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed  Deaths
# 0 -14.2710 -170.1320            American Samoa, US  1/22/20          0       0
# 1  13.4443  144.7937                      Guam, US  1/22/20          0       0
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0       0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0       0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0       0

# %%
us_full_table.loc[us_full_table['Country_Region'] == "US", "Country_Region"] = "USA"

# %%
us_full_table[(us_full_table['Province_State'] == "Maryland" )
                  & (us_full_table['Admin2'] == "Montgomery")]
# Out:
#              UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 1212    84024031   US  USA    840  24031.0  Montgomery       Maryland
# 4481    84024031   US  USA    840  24031.0  Montgomery       Maryland
# 7750    84024031   US  USA    840  24031.0  Montgomery       Maryland
# 11019   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 14288   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 17557   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 20826   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 24095   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 27364   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 30633   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 33902   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 37171   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 40440   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 43709   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 46978   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 50247   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 53516   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 56785   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 60054   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 63323   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 66592   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 69861   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 73130   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 76399   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 79668   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 82937   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 86206   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 89475   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 92744   84024031   US  USA    840  24031.0  Montgomery       Maryland
# 96013   84024031   US  USA    840  24031.0  Montgomery       Maryland
# ...          ...  ...  ...    ...      ...         ...            ...
# 200621  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 203890  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 207159  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 210428  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 213697  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 216966  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 220235  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 223504  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 226773  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 230042  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 233311  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 236580  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 239849  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 243118  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 246387  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 249656  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 252925  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 256194  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 259463  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 262732  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 266001  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 269270  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 272539  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 275808  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 279077  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 282346  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 285615  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 288884  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 292153  84024031   US  USA    840  24031.0  Montgomery       Maryland
# 295422  84024031   US  USA    840  24031.0  Montgomery       Maryland
#
#        Country_Region        Lat      Long_              Combined_Key  \
# 1212              USA  39.136763 -77.203582  Montgomery, Maryland, US
# 4481              USA  39.136763 -77.203582  Montgomery, Maryland, US
# 7750              USA  39.136763 -77.203582  Montgomery, Maryland, US
# 11019             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 14288             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 17557             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 20826             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 24095             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 27364             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 30633             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 33902             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 37171             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 40440             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 43709             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 46978             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 50247             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 53516             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 56785             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 60054             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 63323             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 66592             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 69861             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 73130             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 76399             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 79668             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 82937             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 86206             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 89475             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 92744             USA  39.136763 -77.203582  Montgomery, Maryland, US
# 96013             USA  39.136763 -77.203582  Montgomery, Maryland, US
# ...               ...        ...        ...                       ...
# 200621            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 203890            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 207159            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 210428            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 213697            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 216966            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 220235            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 223504            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 226773            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 230042            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 233311            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 236580            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 239849            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 243118            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 246387            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 249656            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 252925            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 256194            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 259463            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 262732            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 266001            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 269270            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 272539            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 275808            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 279077            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 282346            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 285615            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 288884            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 292153            USA  39.136763 -77.203582  Montgomery, Maryland, US
# 295422            USA  39.136763 -77.203582  Montgomery, Maryland, US
#
#            Date  Confirmed  Deaths
# 1212    1/22/20          0       0
# 4481    1/23/20          0       0
# 7750    1/24/20          0       0
# 11019   1/25/20          0       0
# 14288   1/26/20          0       0
# 17557   1/27/20          0       0
# 20826   1/28/20          0       0
# 24095   1/29/20          0       0
# 27364   1/30/20          0       0
# 30633   1/31/20          0       0
# 33902    2/1/20          0       0
# 37171    2/2/20          0       0
# 40440    2/3/20          0       0
# 43709    2/4/20          0       0
# 46978    2/5/20          0       0
# 50247    2/6/20          0       0
# 53516    2/7/20          0       0
# 56785    2/8/20          0       0
# 60054    2/9/20          0       0
# 63323   2/10/20          0       0
# 66592   2/11/20          0       0
# 69861   2/12/20          0       0
# 73130   2/13/20          0       0
# 76399   2/14/20          0       0
# 79668   2/15/20          0       0
# 82937   2/16/20          0       0
# 86206   2/17/20          0       0
# 89475   2/18/20          0       0
# 92744   2/19/20          0       0
# 96013   2/20/20          0       0
# ...         ...        ...     ...
# 200621  3/23/20         94       1
# 203890  3/24/20        107       1
# 207159  3/25/20        127       1
# 210428  3/26/20        164       1
# 213697  3/27/20        208       1
# 216966  3/28/20        255       1
# 220235  3/29/20        301       1
# 223504  3/30/20        341       1
# 226773  3/31/20        388       1
# 230042   4/1/20        447       1
# 233311   4/2/20        498       6
# 236580   4/3/20        566       9
# 239849   4/4/20        640       9
# 243118   4/5/20        693      13
# 246387   4/6/20        793      19
# 249656   4/7/20        871      21
# 252925   4/8/20       1088      26
# 256194   4/9/20       1214      30
# 259463  4/10/20       1388      34
# 262732  4/11/20       1537      36
# 266001  4/12/20       1631      42
# 269270  4/13/20       1756      48
# 272539  4/14/20       1883      54
# 275808  4/15/20       1933      54
# 279077  4/16/20       2133      56
# 282346  4/17/20       2280      63
# 285615  4/18/20       2404      86
# 288884  4/19/20       2507      96
# 292153  4/20/20       2647     106
# 295422  4/21/20       2768     116
#
# [91 rows x 14 columns]

# %%
us_full_table.to_csv('./COVID-19-data-US/usa_county_wise.csv', index=False)
