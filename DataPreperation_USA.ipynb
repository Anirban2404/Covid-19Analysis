# %% [raw]
# ## Retriving Dataset
# ## https://github.com/CSSEGISandData/COVID-19.git
# ## ! python3 -m pip install wget
# ## ! python3 -m pip install pandas
# ## !python3 -m pip install pycountry_convert

# %%
import pandas as pd
import numpy as np

import wget
import os, datetime
import shutil

import pycountry_convert as pc

# %%
# global csv files
csv_confirmed = "time_series_covid19_confirmed_US.csv"
csv_deaths = "time_series_covid19_deaths_US.csv"

# %%
# urls of the files
urls = ['https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv', 
        'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv']

# download files
for url in urls:
    filename = wget.download(url)

# %%
currDir = "./COVID-19-data-US"

isdir = os.path.isdir(currDir) 

if isdir:
    try:
        shutil.rmtree(currDir, ignore_errors=True)
    except OSError:
        print ("Deletition of the directory %s failed" % currDir)

try:
    os.mkdir(currDir)
except OSError:
    print ("Creation of the directory %s failed" % currDir)
else:
    print ("Successfully created the directory %s " % currDir)

# %%
for file in os.listdir(os.getcwd()):
    if '.csv' in file:
        print(file)
        shutil.move(file, currDir)
# Out:
# time_series_covid19_confirmed_US.csv
# time_series_covid19_deaths_US.csv

# %%
# Datasets loaded to DataFrame
df_confirmed = pd.read_csv("./COVID-19-data-US/time_series_covid19_confirmed_US.csv")
df_deaths = pd.read_csv("./COVID-19-data-US/time_series_covid19_deaths_US.csv")

# %%
df_confirmed.columns
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_',
#        ...
#        '5/7/20', '5/8/20', '5/9/20', '5/10/20', '5/11/20', '5/12/20',
#        '5/13/20', '5/14/20', '5/15/20', '5/16/20'],
#       dtype='object', length=127)

# %%
ids = df_confirmed.columns[0:11]
us_dates = df_confirmed.columns[11:]

us_conf_df_long = df_confirmed.melt(id_vars=ids, value_vars=us_dates, var_name='Date', value_name='Confirmed')
us_deaths_df_long = df_deaths.melt(id_vars=ids, value_vars=us_dates, var_name='Date', value_name='Deaths')

print(us_conf_df_long.shape)
print(us_deaths_df_long.shape)
# Out:
# (378276, 13)
# (378276, 13)

# %%
us_conf_df_long.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed
# 0 -14.2710 -170.1320            American Samoa, US  1/22/20          0
# 1  13.4443  144.7937                      Guam, US  1/22/20          0
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0

# %%
ft_ids = us_conf_df_long.columns[:-1]
ft_ids
# Out:
# Index(['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
#        'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Date'],
#       dtype='object')

# %%
us_full_table = pd.concat([us_conf_df_long, us_deaths_df_long[['Deaths']]], axis=1)
us_full_table.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed  Deaths
# 0 -14.2710 -170.1320            American Samoa, US  1/22/20          0       0
# 1  13.4443  144.7937                      Guam, US  1/22/20          0       0
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0       0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0       0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0       0

# %%
us_full_table.loc[us_full_table['Country_Region'] == "US", "Country_Region"] = "USA"

# %%
us_full_table[(us_full_table['Province_State'] == "Maryland" )
                  & (us_full_table['Admin2'] == "Montgomery")]
# Out:
#              UID iso2 iso3  code3     FIPS      Admin2 Province_State  \
# 1212    84024031   US  USA    840  24031.0  Montgomery       Maryland
# 4473    84024031   US  USA    840  24031.0  Montgomery       Maryland
# 7734    84024031   US  USA    840  24031.0  Montgomery       Maryland
# 10995   84024031   US  USA    840  24031.0  Montgomery       Maryland
#
# 314268 2020-04-27       3843     210
# 317529 2020-04-28       4003     221
# 320790 2020-04-29       4152     242
# 324051 2020-04-30       4300     255
# 327312 2020-05-01       4754     262
# 330573 2020-05-02       4919     282
# 333834 2020-05-03       5150     295
# 337095 2020-05-04       5384     301
# 340356 2020-05-05       5541     320
# 343617 2020-05-06       5790     333
# 346878 2020-05-07       6032     345
# 350139 2020-05-08       6316     355
# 353400 2020-05-09       6555     369
# 356661 2020-05-10       6762     382
# 359922 2020-05-11       6909     388
# 363183 2020-05-12       7130     407
# 366444 2020-05-13       7283     422
# 369705 2020-05-14       7548     437
# 372966 2020-05-15       7759     449
# 376227 2020-05-16       7988     461
#
# [116 rows x 14 columns]

# %%
del us_full_table['Combined_Key']
us_full_table.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa            USA
# 1  316   GU  GUM    316  66.0    NaN                      Guam            USA
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands            USA
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico            USA
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands            USA
#
#        Lat     Long_       Date  Confirmed  Deaths
# 0 -14.2710 -170.1320 2020-01-22          0       0
# 1  13.4443  144.7937 2020-01-22          0       0
# 2  15.0979  145.6739 2020-01-22          0       0
# 3  18.2208  -66.5901 2020-01-22          0       0
# 4  18.3358  -64.8963 2020-01-22          0       0

# %%
pd.to_datetime(us_full_table.Date)
# Out:
# 0        2020-01-22
# 1        2020-01-22
# 2        2020-01-22
# 3        2020-01-22
# 4        2020-01-22
# 5        2020-01-22
# 6        2020-01-22
# 7        2020-01-22
# 8        2020-01-22
# 9        2020-01-22
# 10       2020-01-22
# 11       2020-01-22
# 12       2020-01-22
# 13       2020-01-22
# 14       2020-01-22
# 15       2020-01-22
# 16       2020-01-22
# 17       2020-01-22
# 18       2020-01-22
# 19       2020-01-22
# 20       2020-01-22
# 21       2020-01-22
# 22       2020-01-22
# 23       2020-01-22
# 24       2020-01-22
# 25       2020-01-22
# 26       2020-01-22
# 27       2020-01-22
# 28       2020-01-22
# 29       2020-01-22
#             ...
# 378246   2020-05-16
# 378247   2020-05-16
# 378248   2020-05-16
# 378249   2020-05-16
# 378250   2020-05-16
# 378251   2020-05-16
# 378252   2020-05-16
# 378253   2020-05-16
# 378254   2020-05-16
# 378255   2020-05-16
# 378256   2020-05-16
# 378257   2020-05-16
# 378258   2020-05-16
# 378259   2020-05-16
# 378260   2020-05-16
# 378261   2020-05-16
# 378262   2020-05-16
# 378263   2020-05-16
# 378264   2020-05-16
# 378265   2020-05-16
# 378266   2020-05-16
# 378267   2020-05-16
# 378268   2020-05-16
# 378269   2020-05-16
# 378270   2020-05-16
# 378271   2020-05-16
# 378272   2020-05-16
# 378273   2020-05-16
# 378274   2020-05-16
# 378275   2020-05-16
# Name: Date, Length: 378276, dtype: datetime64[ns]

# %%
us_full_table['Date'] = pd.to_datetime(us_full_table.Date)
us_full_table.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa            USA
# 1  316   GU  GUM    316  66.0    NaN                      Guam            USA
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands            USA
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico            USA
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands            USA
#
#        Lat     Long_       Date  Confirmed  Deaths
# 0 -14.2710 -170.1320 2020-01-22          0       0
# 1  13.4443  144.7937 2020-01-22          0       0
# 2  15.0979  145.6739 2020-01-22          0       0
# 3  18.2208  -66.5901 2020-01-22          0       0
# 4  18.3358  -64.8963 2020-01-22          0       0

# %%
us_full_table.to_csv('./COVID-19-data-US/usa_county_wise.csv', index=False)

# %%
for column in us_full_table.columns:
    print (column)
